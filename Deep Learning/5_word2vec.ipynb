# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'a', 'originated', 'of', 'term', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.249670
# Nearest to over: aggressors, tehran, dawn, trinomial, eponym, chain, myriad, vinge,
# Nearest to and: utf, lancer, irda, athena, teens, blaxploitation, sardaukar, xun,
# Nearest to his: chandrasekhar, schottenheimer, lempel, insubordination, ncipe, lughnasadh, victims, altaic,
# Nearest to is: mdma, feynman, sanitary, microfluidics, transformed, toxin, conceptualization, escudo,
# Nearest to d: appreciation, brando, distillers, bernardino, laing, appendages, waikato, cranial,
# Nearest to be: archimandrite, mppc, subjectivism, diary, quaternions, ankle, britanniae, shutter,
# Nearest to no: red, tenuous, slade, fielding, morphism, sputnik, coloane, anu,
# Nearest to their: anastasius, mirabilis, csc, trentino, hendrick, regulars, vacant, mem,
# Nearest to nine: colombia, nitrate, demands, possum, heinous, sem, concession, minigun,
# Nearest to about: nymph, monotonous, plotter, glockenspiel, christa, shows, ltd, imprecise,
# Nearest to states: spr, dioscorus, zug, vaginal, toolbox, bokken, severn, picchi,
# Nearest to world: rohypnol, bhp, swaim, breslau, ulmanis, mosfet, argon, calm,
# Nearest to state: paleontology, armand, overdosing, erg, likelihood, seaman, ely, asser,
# Nearest to so: reassessment, rupert, astronomer, infix, steal, passively, caspar, menabrea,
# Nearest to by: shots, polyalphabetic, hyksos, carabiners, raccoons, strap, gills, transhuman,
# Nearest to people: quadruple, secam, structuring, generic, epicenter, rallying, aziz, chopped,
# Average loss at step 2000: 4.366732
# Average loss at step 4000: 3.867343
# Average loss at step 6000: 3.788337
# Average loss at step 8000: 3.692556
# Average loss at step 10000: 3.620615
# Nearest to over: zulu, tehran, aggressors, dawn, myriad, disclosed, bahri, eponym,
# Nearest to and: or, s, tunnel, but, in, american, of, were,
# Nearest to his: their, the, its, s, her, cautiously, headset, this,
# Nearest to is: was, are, has, empirically, megabits, be, gemological, were,
# Nearest to d: appreciation, distillers, brando, towns, radial, ch, grote, bernardino,
# Nearest to be: have, subjectivism, was, ovule, is, been, vasa, burials,
# Nearest to no: hitchcock, red, coloane, it, slings, also, sul, enemies,
# Nearest to their: his, regulars, its, the, her, mirabilis, intercession, mafiosi,
# Nearest to nine: eight, six, seven, five, three, zero, four, two,
# Nearest to about: christa, devourer, dude, nymph, ngos, promptly, monotonous, modernist,
# Nearest to states: blonde, spr, babel, hint, nuts, adheres, vibrate, coup,
# Nearest to world: bhp, komodo, book, mosfet, trask, jurors, substrate, swaim,
# Nearest to state: paleontology, seaman, thickness, navajo, academy, overdosing, dunant, highs,
# Nearest to so: rupert, caspar, inositol, steal, dedicated, splash, cham, passively,
# Nearest to by: on, been, through, flattened, was, at, identically, yuma,
# Nearest to people: caste, envisaged, devote, quadruple, inconsistently, excursion, deprecated, aziz,
# Average loss at step 12000: 3.604260
# Average loss at step 14000: 3.575402
# Average loss at step 16000: 3.411870
# Average loss at step 18000: 3.460150
# Average loss at step 20000: 3.540317
# Nearest to over: zulu, tehran, into, bahri, now, disclosed, nylon, orion,
# Nearest to and: or, but, at, american, robust, silicate, from, although,
# Nearest to his: their, her, its, the, some, this, enthusiastic, mcqueen,
# Nearest to is: was, are, has, be, but, were, empirically, at,
# Nearest to d: b, agatha, radial, ch, appreciation, singular, towns, distillers,
# Nearest to be: been, have, was, were, is, ovule, become, by,
# Nearest to no: coloane, hitchcock, sul, ukiyo, nugget, slings, a, it,
# Nearest to their: his, its, her, the, regulars, some, any, skeletal,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to about: christa, ngos, expander, abrahamic, irregularities, kongo, fanatic, fw,
# Nearest to states: babel, spr, nuts, hint, blonde, severn, coup, schoenberg,
# Nearest to world: bhp, komodo, mosfet, trask, book, swaim, jurors, positively,
# Nearest to state: paleontology, navajo, ragnar, neighbor, monotonous, antennae, name, delays,
# Nearest to so: rupert, caspar, inositol, steal, specificity, dedicated, splash, scrolling,
# Nearest to by: through, into, were, be, polyalphabetic, in, xx, foetus,
# Nearest to people: caste, devote, manganese, excursion, envisaged, deprecated, units, notoriety,
# Average loss at step 22000: 3.501193
# Average loss at step 24000: 3.486748
# Average loss at step 26000: 3.483165
# Average loss at step 28000: 3.478276
# Average loss at step 30000: 3.502661
# Nearest to over: into, orion, tehran, annually, myriad, zulu, bahri, boolean,
# Nearest to and: or, but, who, however, in, kip, batting, capacitance,
# Nearest to his: their, her, its, the, s, our, whose, bargain,
# Nearest to is: was, has, are, had, though, gemological, be, but,
# Nearest to d: b, agatha, ch, appreciation, jordi, bner, arndt, wares,
# Nearest to be: been, have, become, ovule, refer, were, was, burials,
# Nearest to no: there, lavender, nugget, any, a, blowfish, cedar, retroviral,
# Nearest to their: its, his, her, the, some, regulars, our, these,
# Nearest to nine: eight, six, seven, four, five, three, zero, two,
# Nearest to about: ngos, abrahamic, expander, pj, christa, singly, fanatic, devourer,
# Nearest to states: state, spr, babel, schoenberg, blonde, adheres, darryl, severn,
# Nearest to world: bhp, komodo, mosfet, swaim, trask, book, positively, range,
# Nearest to state: paleontology, states, monotonous, macross, navajo, neighbor, ragnar, tg,
# Nearest to so: rupert, scrolling, caspar, inositol, too, fledgling, analog, splash,
# Nearest to by: under, through, movies, in, was, ita, marinetti, dis,
# Nearest to people: caste, manganese, go, jews, excursion, blackmail, berber, rulers,
# Average loss at step 32000: 3.499970
# Average loss at step 34000: 3.494791
# Average loss at step 36000: 3.454965
# Average loss at step 38000: 3.305705
# Average loss at step 40000: 3.431510
# Nearest to over: into, about, nist, zulu, cores, heiden, at, approximately,
# Nearest to and: or, but, macworld, through, hayling, caenorhabditis, are, mel,
# Nearest to his: their, her, its, my, the, our, whose, raza,
# Nearest to is: was, are, has, be, surmounted, bmi, icmp, became,
# Nearest to d: b, agatha, ch, UNK, notate, waikato, iso, appreciation,
# Nearest to be: been, have, ovule, by, was, become, kryptonians, is,
# Nearest to no: any, nugget, lavender, always, typically, coloane, uniqueness, cira,
# Nearest to their: its, his, her, the, regulars, some, these, any,
# Nearest to nine: eight, seven, six, zero, five, four, three, two,
# Nearest to about: ngos, abrahamic, over, expander, habits, irregularities, jellyfish, nvidia,
# Nearest to states: state, countries, kingdom, spr, babel, adheres, lamont, indiscriminate,
# Nearest to world: komodo, bhp, mosfet, swaim, edomites, u, sheryl, zhaozhou,
# Nearest to state: paleontology, states, macross, navajo, congress, ragnar, government, neighbor,
# Nearest to so: fledgling, caspar, rupert, scrolling, inositol, too, enduring, analog,
# Nearest to by: be, was, as, with, for, through, omens, partisan,
# Nearest to people: caste, lamborghini, those, forcing, companies, quadruple, rulers, jews,
# Average loss at step 42000: 3.438565
# Average loss at step 44000: 3.452647
# Average loss at step 46000: 3.447184
# Average loss at step 48000: 3.355217
# Average loss at step 50000: 3.383441
# Nearest to over: into, through, nist, zulu, about, cores, matt, boolean,
# Nearest to and: or, but, of, receded, s, through, ste, including,
# Nearest to his: her, their, its, my, the, our, whose, raza,
# Nearest to is: was, has, are, became, does, gemological, be, if,
# Nearest to d: b, ch, m, agatha, notate, iso, e, rebadged,
# Nearest to be: been, have, become, was, were, being, lead, are,
# Nearest to no: any, little, lavender, persists, encyclopedic, nugget, uncensored, bayonne,
# Nearest to their: its, his, her, the, our, regulars, some, any,
# Nearest to nine: eight, seven, six, four, three, zero, five, two,
# Nearest to about: ngos, irregularities, over, circumcising, nvidia, stamps, abrahamic, consonances,
# Nearest to states: kingdom, state, countries, indiscriminate, nations, schoenberg, spr, darryl,
# Nearest to world: mosfet, komodo, bhp, vocabulary, swaim, zhaozhou, dao, u,
# Nearest to state: paleontology, states, macross, navajo, neighbor, ragnar, government, roadway,
# Nearest to so: if, then, fledgling, cystic, kinetochores, too, inositol, caspar,
# Nearest to by: through, under, was, movies, clown, butyl, siddhartha, with,
# Nearest to people: caste, jews, lamborghini, men, shamanic, ito, notoriety, blackmail,
# Average loss at step 52000: 3.434019
# Average loss at step 54000: 3.426642
# Average loss at step 56000: 3.438023
# Average loss at step 58000: 3.396810
# Average loss at step 60000: 3.392691
# Nearest to over: into, nist, about, through, hampering, conservatives, boolean, hundred,
# Nearest to and: or, but, including, although, tiling, than, like, batting,
# Nearest to his: her, their, its, my, our, the, whose, headset,
# Nearest to is: was, are, has, makes, although, seems, be, gemological,
# Nearest to d: b, m, h, ch, l, agatha, e, requiem,
# Nearest to be: been, become, was, kryptonians, refer, is, are, were,
# Nearest to no: any, little, lavender, guises, hitchcock, uncensored, nugget, persists,
# Nearest to their: its, his, her, the, some, whose, your, our,
# Nearest to nine: eight, six, seven, four, five, zero, three, one,
# Nearest to about: ngos, over, nvidia, stamps, abrahamic, irregularities, fanatic, denis,
# Nearest to states: countries, kingdom, nations, state, indiscriminate, blonde, venera, crockett,
# Nearest to world: komodo, mosfet, vocabulary, glover, bhp, zhaozhou, swaim, constitutional,
# Nearest to state: states, government, iamblichus, ragnar, goal, citizen, monotonous, maduro,
# Nearest to so: if, too, then, fledgling, cystic, scrolling, magellanic, argues,
# Nearest to by: through, polyalphabetic, siddhartha, xx, pity, beastie, using, warm,
# Nearest to people: men, jews, fans, caste, those, lamborghini, songs, shamanic,
# Average loss at step 62000: 3.240763
# Average loss at step 64000: 3.253139
# Average loss at step 66000: 3.406566
# Average loss at step 68000: 3.394952
# Average loss at step 70000: 3.357942
# Nearest to over: filesystems, into, about, wallis, doves, nist, conservatives, hampering,
# Nearest to and: or, but, which, than, like, franchisee, while, receded,
# Nearest to his: her, their, its, my, our, whose, the, him,
# Nearest to is: was, has, are, be, although, makes, requires, became,
# Nearest to d: b, h, m, orf, ch, r, iso, f,
# Nearest to be: been, become, is, were, was, have, being, kryptonians,
# Nearest to no: little, any, guises, there, encyclopedic, hitchcock, nugget, persists,
# Nearest to their: its, his, her, the, your, our, some, regulars,
# Nearest to nine: eight, six, seven, four, five, three, zero, one,
# Nearest to about: over, irregularities, stamps, ngos, rilke, nvidia, abrahamic, on,
# Nearest to states: kingdom, nations, countries, state, schoenberg, detectives, highbury, spr,
# Nearest to world: komodo, mosfet, glover, vocabulary, zhaozhou, shave, dimaggio, locally,
# Nearest to state: states, government, city, monotonous, tequila, yukio, ragnar, goal,
# Nearest to so: too, then, thus, if, scrolling, fledgling, how, pei,
# Nearest to by: polyalphabetic, using, through, intrusions, be, waterfowl, from, occurrences,
# Nearest to people: men, caste, fans, children, jews, manganese, yuen, women,
# Average loss at step 72000: 3.373469
# Average loss at step 74000: 3.347457
# Average loss at step 76000: 3.318064
# Average loss at step 78000: 3.353354
# Average loss at step 80000: 3.375325
# Nearest to over: into, through, wallis, about, around, throughout, filesystems, nist,
# Nearest to and: or, but, including, jockey, propellers, mathbf, although, than,
# Nearest to his: her, their, its, my, our, your, whose, the,
# Nearest to is: was, has, are, although, gemological, became, remains, does,
# Nearest to d: b, h, ch, m, iso, agatha, orf, e,
# Nearest to be: been, become, have, being, kryptonians, refer, was, easily,
# Nearest to no: little, any, persists, hitchcock, uncensored, guises, uniqueness, always,
# Nearest to their: its, his, her, your, our, the, these, my,
# Nearest to nine: eight, seven, five, six, four, three, zero, two,
# Nearest to about: stamps, over, ngos, mens, firefighters, schiff, approximately, irregularities,
# Nearest to states: kingdom, nations, countries, state, lamont, schoenberg, detectives, darryl,
# Nearest to world: komodo, mosfet, vocabulary, glover, zhaozhou, u, carriers, botswana,
# Nearest to state: states, city, government, goal, cornell, ragnar, navajo, task,
# Nearest to so: then, too, if, how, pei, suggested, scrolling, fledgling,
# Nearest to by: through, polyalphabetic, using, from, girlfriends, ashkenazic, avc, under,
# Nearest to people: children, men, caste, fans, women, those, jews, yuen,
# Average loss at step 82000: 3.406279
# Average loss at step 84000: 3.411007
# Average loss at step 86000: 3.393376
# Average loss at step 88000: 3.350689
# Average loss at step 90000: 3.365243
# Nearest to over: into, through, off, nist, about, under, cores, tempering,
# Nearest to and: or, but, including, while, although, caenorhabditis, guadalupe, batting,
# Nearest to his: her, their, its, my, our, your, the, whose,
# Nearest to is: was, has, are, although, be, makes, became, does,
# Nearest to d: b, h, iso, ch, orf, toolkits, dick, agatha,
# Nearest to be: been, become, is, have, was, kryptonians, refer, being,
# Nearest to no: little, any, only, persists, always, recognisable, there, skeletons,
# Nearest to their: its, his, her, your, our, whose, both, my,
# Nearest to nine: eight, seven, five, six, four, zero, three, two,
# Nearest to about: over, circumcising, charlottetown, absurdum, ssang, backplane, mens, stamps,
# Nearest to states: kingdom, nations, countries, state, darryl, lamont, indiscriminate, nazis,
# Nearest to world: komodo, glover, mosfet, zhaozhou, vocabulary, matra, broaden, suspects,
# Nearest to state: states, government, city, delays, navajo, yukio, cornell, ragnar,
# Nearest to so: too, thus, if, fledgling, then, pei, how, theology,
# Nearest to by: through, under, using, polyalphabetic, when, without, universite, avc,
# Nearest to people: men, children, women, jews, those, fans, yuen, members,
# Average loss at step 92000: 3.397608
# Average loss at step 94000: 3.257403
# Average loss at step 96000: 3.360653
# Average loss at step 98000: 3.243702
# Average loss at step 100000: 3.356918
# Nearest to over: into, through, about, around, off, within, boolean, approximately,
# Nearest to and: but, or, however, although, while, including, when, caenorhabditis,
# Nearest to his: her, their, my, its, your, our, the, s,
# Nearest to is: was, became, has, are, be, although, octopussy, includes,
# Nearest to d: b, ch, orf, h, r, toolkits, j, dispensationalism,
# Nearest to be: been, become, refer, have, are, is, being, kryptonians,
# Nearest to no: any, only, little, recognisable, uncensored, mangrove, there, persists,
# Nearest to their: its, his, her, your, our, the, my, whose,
# Nearest to nine: eight, seven, six, four, five, three, zero, two,
# Nearest to about: over, ssang, circumcising, tetum, absurdum, mens, ngos, charlottetown,
# Nearest to states: kingdom, nations, countries, state, darryl, lamont, schoenberg, crafts,
# Nearest to world: komodo, matra, mosfet, glover, vocabulary, zhaozhou, botswana, country,
# Nearest to state: states, city, government, whoever, iamblichus, multicultural, ferranti, machen,
# Nearest to so: too, thus, when, then, if, fledgling, activated, how,
# Nearest to by: including, without, through, polyalphabetic, siddhartha, during, when, with,
# Nearest to people: jews, fans, men, children, women, yuen, those, players,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
